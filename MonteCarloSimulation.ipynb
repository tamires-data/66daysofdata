# %%
from pandas_datareader import data

df = data.get_data_yahoo("SPY")
df['return'] = df['Adj Close'].pct_change().fillna(0)

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2016-06-09  212.220001  211.190002  211.509995  212.080002   73786900.0
# 2016-06-10  210.860001  209.429993  210.460007  210.070007  113829200.0
# 2016-06-13  210.369995  208.350006  209.360001  208.449997  117751200.0
# 2016-06-14  208.740005  206.919998  208.000000  208.039993  125059300.0
# 2016-06-15  209.360001  207.529999  208.039993  207.750000  109124500.0
# ...                ...         ...         ...         ...          ...
# 2021-06-02  421.230011  419.290009  420.369995  420.329987   49097100.0
# 2021-06-03  419.989990  416.279999  417.850006  418.769989   58138800.0
# 2021-06-04  422.920013  418.839996  420.750000  422.600006   55910700.0
# 2021-06-07  422.779999  421.190002  422.589996  422.190002   51450000.0
# 2021-06-08  423.200012  420.320007  423.109985  422.279999   46328938.0
#
#              Adj Close    return
# Date
# 2016-06-09  192.916718  0.000000
# 2016-06-10  191.088379 -0.009477
# 2016-06-13  189.614746 -0.007712
# 2016-06-14  189.241791 -0.001967
# 2016-06-15  188.977982 -0.001394
# ...                ...       ...
# 2021-06-02  420.329987  0.001573
# 2021-06-03  418.769989 -0.003711
# 2021-06-04  422.600006  0.009146
# 2021-06-07  422.190002 -0.000970
# 2021-06-08  422.279999  0.000213
#
# [1258 rows x 7 columns]

# %%
import pandas_montecarlo
mc = df['return'].montecarlo(sims=10, bust=-0.1, goal=1)

# %%
mc.plot(title="SPY Returns Monte Carlo Simulations")
